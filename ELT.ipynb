# %% [markdown]
# # ELT script
# - ELT is just you do the transform data step inside the datawarehouse or in database enviroment is my case is MySQL and using SQL to transform data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## This SQL code is use to summarize user data per day
# - How many user active per day
# - What is total duration of Relax Category
# - What is total duration of Movie Category
# - What is total duration of Child Category
# - What is total duration of Sport Category
# - What is total duration of Tv Category
# - The specific Date

# %% [markdown]
# # NOTE
# - Make sure your date column is in correct data type
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
# - Use this function to get current date (in real life scenario this job will be trigger everyday)

# %% [markdown]
# ### Create a stored procedure that can be use in MySQL event schedule as a job and will automatically run everyday at 23pm
# - This job will import all data from the previous day to the data mart, so that on the next day morning the other member of the teams such as Data Analyst or Data Scientist will have the data ready for their task.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Data inside the data mart after 2 days
# ![image.png](attachment:image.png)
